# %%
import pandas as pd
match= pd.read_csv('../data/matches.csv')
delivery= pd.read_csv('../data/deliveries.csv')

# %%
#Normal Function
display(match.head())
match.head(1)
match.info()
delivery.info()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
#access the dataframe
match[['id','season','venue']]
access_1=match.loc[(match.season>'2017') & (match.team1=='Mumbai Indians')]
#access the dataframe
con1=match.season>'2017'
con2=match.team1=='Mumbai Indians'
access_2=match[con1 & con2]
access_1==access_2
print(display(access_1['city'].value_counts()))
print(display(access_1['city'].sort_values(ascending=False)))
# Out:
# city
# Mumbai         15
# Chennai         8
# Abu Dhabi       7
# Hyderabad       4
# Jaipur          3
# Bengaluru       2
# Pune            2
# Kolkata         1
# Chandigarh      1
# Delhi           1
# Sharjah         1
# Navi Mumbai     1
# Mohali          1
# Lucknow         1
# Name: count, dtype: int64
# None
# 862         Sharjah
# 889            Pune
# 893            Pune
# 908     Navi Mumbai
# 636          Mumbai
# 746          Mumbai
# 926          Mumbai
# 722          Mumbai
# 961          Mumbai
# 710          Mumbai
# 1006         Mumbai
# 1037         Mumbai
# 685          Mumbai
# 682          Mumbai
# 1043         Mumbai
# 672          Mumbai
# 649          Mumbai
# 644          Mumbai
# 877          Mumbai
# 1056         Mohali
# 1071        Lucknow
# 676         Kolkata
# 1061         Jaipur
# 656          Jaipur
# 731          Jaipur
# 755       Hyderabad
# 642       Hyderabad
# 974       Hyderabad
# 714       Hyderabad
# 729           Delhi
# 739         Chennai
# 1021        Chennai
# 998         Chennai
# 816         Chennai
# 832         Chennai
# 828         Chennai
# 824         Chennai
# 820         Chennai
# 704      Chandigarh
# 954       Bengaluru
# 702       Bengaluru
# 775       Abu Dhabi
# 756       Abu Dhabi
# 870       Abu Dhabi
# 760       Abu Dhabi
# 849       Abu Dhabi
# 799       Abu Dhabi
# 768       Abu Dhabi
# 773             NaN
# 791             NaN
# 811             NaN
# 812             NaN
# Name: city, dtype: object
# None

# %%
#group by
stats_player=delivery.groupby('batter')

# %%
display(stats_player.size())
# Out:
# batter
# A Ashish Reddy     196
# A Badoni           505
# A Chandila           7
# A Chopra            75
# A Choudhary         20
#                   ...
# Yashpal Singh       67
# Younis Khan          7
# Yudhvir Singh       16
# Yuvraj Singh      2207
# Z Khan             141
# Length: 673, dtype: int64

# %%
display(stats_player.first())
# Out:
#                 match_id  inning                 batting_team  \
# batter
# A Ashish Reddy    548346       1              Deccan Chargers
# A Badoni         1304050       1         Lucknow Super Giants
# A Chandila        548373       1             Rajasthan Royals
# A Chopra          336010       1        Kolkata Knight Riders
# A Choudhary      1082591       2  Royal Challengers Bangalore
# ...                  ...     ...                          ...
# Yashpal Singh     392190       2        Kolkata Knight Riders
# Younis Khan       336019       2             Rajasthan Royals
# Yudhvir Singh    1359495       1         Lucknow Super Giants
# Yuvraj Singh      335983       2              Kings XI Punjab
# Z Khan            335982       2  Royal Challengers Bangalore
#
#                                bowling_team  over  ball          bowler  \
# batter
# A Ashish Reddy               Mumbai Indians    13     1     RJ Peterson
# A Badoni                     Gujarat Titans     4     4  Mohammed Shami
# A Chandila                  Deccan Chargers    19     6  V Pratap Singh
# A Chopra        Royal Challengers Bangalore     0     1        DW Steyn
# A Choudhary             Sunrisers Hyderabad    19     3     BCJ Cutting
# ...                                     ...   ...   ...             ...
# Yashpal Singh              Rajasthan Royals    14     2  AD Mascarenhas
# Younis Khan                 Kings XI Punjab     1     4     S Sreesanth
# Yudhvir Singh                  Punjab Kings    19     5       SM Curran
# Yuvraj Singh            Chennai Super Kings    10     4      P Amarnath
# Z Khan                Kolkata Knight Riders    11     2      SC Ganguly
#
#                   non_striker  batsman_runs  extra_runs  total_runs  \
# batter
# A Ashish Reddy      JP Duminy             0           0           0
# A Badoni             DJ Hooda             0           0           0
# A Chandila            OA Shah             0           0           0
# A Chopra             BJ Hodge             0           0           0
# A Choudhary         YS Chahal             6           0           6
# ...                       ...           ...         ...         ...
# Yashpal Singh      SC Ganguly             0           0           0
# Younis Khan          NK Patel             1           0           1
# Yudhvir Singh        A Badoni             0           0           0
# Yuvraj Singh    KC Sangakkara             1           0           1
# Z Khan                P Kumar             0           0           0
#
#                extras_type  is_wicket player_dismissed dismissal_kind  \
# batter
# A Ashish Reddy        byes          0   A Ashish Reddy         caught
# A Badoni             wides          0         A Badoni         caught
# A Chandila            None          1          OA Shah        run out
# A Chopra             wides          0         A Chopra            lbw
# A Choudhary           None          0        YS Chahal        run out
# ...                    ...        ...              ...            ...
# Yashpal Singh        wides          0    Yashpal Singh         caught
# Younis Khan           None          0      Younis Khan         bowled
# Yudhvir Singh         None          1    Yudhvir Singh         caught
# Yuvraj Singh         wides          0     Yuvraj Singh         caught
# Z Khan             noballs          0           Z Khan         bowled
#
#                         fielder
# batter
# A Ashish Reddy        RG Sharma
# A Badoni              HH Pandya
# A Chandila             PA Patel
# A Chopra               HH Gibbs
# A Choudhary           CJ Jordan
# ...                         ...
# Yashpal Singh           AS Raut
# Younis Khan                None
# Yudhvir Singh   M Shahrukh Khan
# Yuvraj Singh         P Amarnath
# Z Khan                 SK Raina
#
# [673 rows x 16 columns]

# %%
display(stats_player.last())
# Out:
#                 match_id  inning                 batting_team  \
# batter
# A Ashish Reddy    980953       1          Sunrisers Hyderabad
# A Badoni         1426305       1         Lucknow Super Giants
# A Chandila        598023       1             Rajasthan Royals
# A Chopra          392184       1        Kolkata Knight Riders
# A Choudhary      1082633       2  Royal Challengers Bangalore
# ...                  ...     ...                          ...
# Yashpal Singh     392233       2        Kolkata Knight Riders
# Younis Khan       336019       2             Rajasthan Royals
# Yudhvir Singh    1426302       2         Lucknow Super Giants
# Yuvraj Singh     1175370       1               Mumbai Indians
# Z Khan           1082646       2             Delhi Daredevils
#
#                                bowling_team  over  ball       bowler  \
# batter
# A Ashish Reddy  Royal Challengers Bangalore    19     6    SR Watson
# A Badoni                     Mumbai Indians    19     7   R Shepherd
# A Chandila      Royal Challengers Bangalore    19     2    R Rampaul
# A Chopra                    Deccan Chargers    10     4      PP Ojha
# A Choudhary                 Kings XI Punjab    18     6    MM Sharma
# ...                                     ...   ...   ...          ...
# Yashpal Singh              Rajasthan Royals     4     7     MM Patel
# Younis Khan                 Kings XI Punjab     4     5    IK Pathan
# Yudhvir Singh                Delhi Capitals    16     7     KK Ahmed
# Yuvraj Singh            Chennai Super Kings     8     3  Imran Tahir
# Z Khan          Royal Challengers Bangalore    19     3       P Negi
#
#                  non_striker  batsman_runs  extra_runs  total_runs  \
# batter
# A Ashish Reddy  MC Henriques             1           0           1
# A Badoni           KH Pandya             0           0           0
# A Chandila        SK Trivedi             1           0           1
# A Chopra            BJ Hodge             0           0           0
# A Choudhary        YS Chahal             0           0           0
# ...                      ...           ...         ...         ...
# Yashpal Singh       BJ Hodge             0           0           0
# Younis Khan         NK Patel             0           0           0
# Yudhvir Singh    Arshad Khan             0           0           0
# Yuvraj Singh        SA Yadav             0           0           0
# Z Khan              S Nadeem             1           0           1
#
#                extras_type  is_wicket player_dismissed dismissal_kind  \
# batter
# A Ashish Reddy       wides          0   A Ashish Reddy        run out
# A Badoni             wides          0         A Badoni         caught
# A Chandila            None          0          OA Shah        run out
# A Chopra           legbyes          1         A Chopra        stumped
# A Choudhary           None          1      A Choudhary         caught
# ...                    ...        ...              ...            ...
# Yashpal Singh      noballs          1    Yashpal Singh         caught
# Younis Khan           None          1      Younis Khan         bowled
# Yudhvir Singh         None          1    Yudhvir Singh         caught
# Yuvraj Singh         wides          1     Yuvraj Singh         caught
# Z Khan                byes          0           Z Khan         caught
#
#                         fielder
# batter
# A Ashish Reddy  Shakib Al Hasan
# A Badoni          Gulbadin Naib
# A Chandila             PA Patel
# A Chopra           AC Gilchrist
# A Choudhary          MJ Guptill
# ...                         ...
# Yashpal Singh         RJ Quiney
# Younis Khan                None
# Yudhvir Singh           SD Hope
# Yuvraj Singh          AT Rayudu
# Z Khan                   N Rana
#
# [673 rows x 16 columns]

# %%
stats_player.get_group('V Kohli')
# Out:
#         match_id  inning                 batting_team           bowling_team  \
# 132       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 133       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 134       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 137       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 138       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# ...          ...     ...                          ...                    ...
# 260280   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
# 260282   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
# 260286   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
# 260287   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
# 260288   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
#
#         over  ball   batter     bowler non_striker  batsman_runs  extra_runs  \
# 132        1     2  V Kohli   I Sharma    W Jaffer             0           0
# 133        1     3  V Kohli   I Sharma    W Jaffer             0           4
# 134        1     4  V Kohli   I Sharma    W Jaffer             1           0
# 137        2     1  V Kohli   AB Dinda    W Jaffer             0           0
# 138        2     2  V Kohli   AB Dinda    W Jaffer             0           0
# ...      ...   ...      ...        ...         ...           ...         ...
# 260280     6     1  V Kohli   R Ashwin     C Green             1           0
# 260282     6     3  V Kohli   R Ashwin     C Green             1           0
# 260286     6     7  V Kohli   R Ashwin     C Green             1           0
# 260287     7     1  V Kohli  YS Chahal     C Green             0           0
# 260288     7     2  V Kohli  YS Chahal     C Green             0           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 132              0         NaN          0              NaN            NaN
# 133              4     legbyes          0              NaN            NaN
# 134              1         NaN          0              NaN            NaN
# 137              0         NaN          0              NaN            NaN
# 138              0         NaN          1          V Kohli         bowled
# ...            ...         ...        ...              ...            ...
# 260280           1         NaN          0              NaN            NaN
# 260282           1         NaN          0              NaN            NaN
# 260286           1         NaN          0              NaN            NaN
# 260287           0         NaN          0              NaN            NaN
# 260288           0         NaN          1          V Kohli         caught
#
#            fielder
# 132            NaN
# 133            NaN
# 134            NaN
# 137            NaN
# 138            NaN
# ...            ...
# 260280         NaN
# 260282         NaN
# 260286         NaN
# 260287         NaN
# 260288  D Ferreira
#
# [6236 rows x 17 columns]

# %%
stats_player.get_group("V Kohli")
# Out:
#         match_id  inning                 batting_team           bowling_team  \
# 132       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 133       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 134       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 137       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# 138       335982       2  Royal Challengers Bangalore  Kolkata Knight Riders
# ...          ...     ...                          ...                    ...
# 260280   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
# 260282   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
# 260286   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
# 260287   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
# 260288   1426310       1  Royal Challengers Bengaluru       Rajasthan Royals
#
#         over  ball   batter     bowler non_striker  batsman_runs  extra_runs  \
# 132        1     2  V Kohli   I Sharma    W Jaffer             0           0
# 133        1     3  V Kohli   I Sharma    W Jaffer             0           4
# 134        1     4  V Kohli   I Sharma    W Jaffer             1           0
# 137        2     1  V Kohli   AB Dinda    W Jaffer             0           0
# 138        2     2  V Kohli   AB Dinda    W Jaffer             0           0
# ...      ...   ...      ...        ...         ...           ...         ...
# 260280     6     1  V Kohli   R Ashwin     C Green             1           0
# 260282     6     3  V Kohli   R Ashwin     C Green             1           0
# 260286     6     7  V Kohli   R Ashwin     C Green             1           0
# 260287     7     1  V Kohli  YS Chahal     C Green             0           0
# 260288     7     2  V Kohli  YS Chahal     C Green             0           0
#
#         total_runs extras_type  is_wicket player_dismissed dismissal_kind  \
# 132              0         NaN          0              NaN            NaN
# 133              4     legbyes          0              NaN            NaN
# 134              1         NaN          0              NaN            NaN
# 137              0         NaN          0              NaN            NaN
# 138              0         NaN          1          V Kohli         bowled
# ...            ...         ...        ...              ...            ...
# 260280           1         NaN          0              NaN            NaN
# 260282           1         NaN          0              NaN            NaN
# 260286           1         NaN          0              NaN            NaN
# 260287           0         NaN          0              NaN            NaN
# 260288           0         NaN          1          V Kohli         caught
#
#            fielder
# 132            NaN
# 133            NaN
# 134            NaN
# 137            NaN
# 138            NaN
# ...            ...
# 260280         NaN
# 260282         NaN
# 260286         NaN
# 260287         NaN
# 260288  D Ferreira
#
# [6236 rows x 17 columns]

# %%
kohli_stats=stats_player.get_group('V Kohli')

# %%
#How many deliveries play by Kohli
print(kohli_stats.shape)
#How many six by Kohli
cond=kohli_stats.batsman_runs==6
print(kohli_stats[cond].shape)
# Out:
# (6236, 17)
# (273, 17)

# %%
#For each batsman
#Sum of Runs for all batsman
stats_player['batsman_runs'].sum().sort_values(ascending=False)
#Top 10 Six Hitter Batsman
cond4=delivery['batsman_runs']==4
cond6=delivery['batsman_runs']==6

six_stats=delivery[cond6].groupby('batter')
six_stats['batsman_runs'].count().sort_values(ascending=False).head(10).to_dict()
# Out:
# {'CH Gayle': 359,
#  'RG Sharma': 281,
#  'V Kohli': 273,
#  'AB de Villiers': 253,
#  'MS Dhoni': 252,
#  'DA Warner': 236,
#  'KA Pollard': 224,
#  'AD Russell': 209,
#  'SV Samson': 206,
#  'SK Raina': 204}

# %%
#last five over highest strick rate batsman
mask1=delivery['over']>15
stats_last_over=delivery[mask1]
stats_last_over.shape
bat_final=stats_last_over.groupby('batter')
#Srick Rate for each batsman
last_over_balls=bat_final['ball'].count()
last_over_runs=bat_final['batsman_runs'].sum()
final_df=pd.concat([last_over_balls,last_over_runs],axis=1)
final_df['strick_rate']=last_over_runs/last_over_balls*100

#batsman who played more than 100 ball in final over NOT Required For Now
last_over_mask_100=bat_final['ball'].count()>100
last_over_batsman=last_over_balls[last_over_mask_100]
last_over_batsman_list=last_over_batsman.index.tolist()

# batsman strick rate  for the batsman played more then 100 balls
final_df[final_df.ball>100].sort_values('strick_rate',ascending=False).reset_index().head(10)
# Out:
#            batter  ball  batsman_runs  strick_rate
# 0  AB de Villiers   635          1421   223.779528
# 1  LS Livingstone   103           204   198.058252
# 2         RR Pant   318           626   196.855346
# 3        CH Gayle   209           404   193.301435
# 4         V Kohli   571          1099   192.469352
# 5       JH Kallis   159           303   190.566038
# 6       H Klaasen   161           306   190.062112
# 7    F du Plessis   220           416   189.090909
# 8       RG Sharma   625          1176   188.160000
# 9        SA Yadav   276           516   186.956522

# %%
#merge on the datasets
match_stats=match.merge(delivery,left_on='id',right_on='match_id')
match_stats.reset_index().head(1)
match_stats.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'match_id', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#match stats for the batsman
match_stats_batsman=match_stats.groupby('batter')
match_stats_batsman['batsman_runs'].sum().sort_values(ascending=False).head(10).to_dict()
# Out:
# {'V Kohli': 8014,
#  'S Dhawan': 6769,
#  'RG Sharma': 6630,
#  'DA Warner': 6567,
#  'SK Raina': 5536,
#  'MS Dhoni': 5243,
#  'AB de Villiers': 5181,
#  'CH Gayle': 4997,
#  'RV Uthappa': 4954,
#  'KD Karthik': 4843}

# %%
#apply function uses
def get_runs(row):
    print(row)
    if row['batsman_runs']>0:
        return row['batsman_runs']
    else:
        return 0

msb=match_stats_batsman['batsman_runs'].sum().sort_values(ascending=False).reset_index() 
msb.head(10)
msb_df=msb.apply(get_runs,axis=1)
# Out:
# batter          V Kohli
# batsman_runs       8014
# Name: 0, dtype: object
# batter          S Dhawan
# batsman_runs        6769
# Name: 1, dtype: object
# batter          RG Sharma
# batsman_runs         6630
# Name: 2, dtype: object
# batter          DA Warner
# batsman_runs         6567
# Name: 3, dtype: object
# batter          SK Raina
# batsman_runs        5536
# Name: 4, dtype: object
# batter          MS Dhoni
# batsman_runs        5243
# Name: 5, dtype: object
# batter          AB de Villiers
# batsman_runs              5181
# Name: 6, dtype: object
# batter          CH Gayle
# batsman_runs        4997
# Name: 7, dtype: object
# batter          RV Uthappa
# batsman_runs          4954
# Name: 8, dtype: object
# batter          KD Karthik
# batsman_runs          4843
# Name: 9, dtype: object
# batter          KL Rahul
# batsman_runs        4689
# Name: 10, dtype: object
# batter          AM Rahane
# batsman_runs         4642
# Name: 11, dtype: object
# batter          F du Plessis
# batsman_runs            4571
# Name: 12, dtype: object
# batter          SV Samson
# batsman_runs         4419
# Name: 13, dtype: object
# batter          AT Rayudu
# batsman_runs         4348
# Name: 14, dtype: object
# batter          G Gambhir
# batsman_runs         4217
# Name: 15, dtype: object
# batter          SR Watson
# batsman_runs         3880
# Name: 16, dtype: object
# batter          MK Pandey
# batsman_runs         3859
# Name: 17, dtype: object
# batter          SA Yadav
# batsman_runs        3594
# Name: 18, dtype: object
# batter          JC Buttler
# batsman_runs          3583
# Name: 19, dtype: object
# batter          KA Pollard
# batsman_runs          3437
# Name: 20, dtype: object
# batter          RR Pant
# batsman_runs       3297
# Name: 21, dtype: object
# batter          YK Pathan
# batsman_runs         3222
# Name: 22, dtype: object
# batter          Shubman Gill
# batsman_runs            3216
# Name: 23, dtype: object
# batter          Q de Kock
# batsman_runs         3160
# Name: 24, dtype: object
# batter          SS Iyer
# batsman_runs       3131
# Name: 25, dtype: object
# batter          RA Jadeja
# batsman_runs         2959
# Name: 26, dtype: object
# batter          WP Saha
# batsman_runs       2934
# Name: 27, dtype: object
# batter          DA Miller
# batsman_runs         2924
# Name: 28, dtype: object
# batter          BB McCullum
# batsman_runs           2882
# Name: 29, dtype: object
# batter          PA Patel
# batsman_runs        2848
# Name: 30, dtype: object
# batter          GJ Maxwell
# batsman_runs          2772
# Name: 31, dtype: object
# batter          Yuvraj Singh
# batsman_runs            2754
# Name: 32, dtype: object
# batter          V Sehwag
# batsman_runs        2728
# Name: 33, dtype: object
# batter          MA Agarwal
# batsman_runs          2669
# Name: 34, dtype: object
# batter          Ishan Kishan
# batsman_runs            2644
# Name: 35, dtype: object
# batter          N Rana
# batsman_runs      2636
# Name: 36, dtype: object
# batter          M Vijay
# batsman_runs       2619
# Name: 37, dtype: object
# batter          HH Pandya
# batsman_runs         2534
# Name: 38, dtype: object
# batter          SPD Smith
# batsman_runs         2495
# Name: 39, dtype: object
# batter          SE Marsh
# batsman_runs        2489
# Name: 40, dtype: object
# batter          AD Russell
# batsman_runs          2488
# Name: 41, dtype: object
# batter          JH Kallis
# batsman_runs         2427
# Name: 42, dtype: object
# batter          DR Smith
# batsman_runs        2385
# Name: 43, dtype: object
# batter          RD Gaikwad
# batsman_runs          2380
# Name: 44, dtype: object
# batter          SR Tendulkar
# batsman_runs            2334
# Name: 45, dtype: object
# batter          RA Tripathi
# batsman_runs           2236
# Name: 46, dtype: object
# batter          R Dravid
# batsman_runs        2174
# Name: 47, dtype: object
# batter          KS Williamson
# batsman_runs             2132
# Name: 48, dtype: object
# batter          AJ Finch
# batsman_runs        2092
# Name: 49, dtype: object
# batter          AC Gilchrist
# batsman_runs            2069
# Name: 50, dtype: object
# batter          JP Duminy
# batsman_runs         2029
# Name: 51, dtype: object
# batter          MEK Hussey
# batsman_runs          1977
# Name: 52, dtype: object
# batter          PP Shaw
# batsman_runs       1892
# Name: 53, dtype: object
# batter          MP Stoinis
# batsman_runs          1866
# Name: 54, dtype: object
# batter          DPMD Jayawardene
# batsman_runs                1808
# Name: 55, dtype: object
# batter          N Pooran
# batsman_runs        1769
# Name: 56, dtype: object
# batter          Mandeep Singh
# batsman_runs             1706
# Name: 57, dtype: object
# batter          MK Tiwary
# batsman_runs         1695
# Name: 58, dtype: object
# batter          KC Sangakkara
# batsman_runs             1687
# Name: 59, dtype: object
# batter          AR Patel
# batsman_runs        1653
# Name: 60, dtype: object
# batter          KH Pandya
# batsman_runs         1647
# Name: 61, dtype: object
# batter          YBK Jaiswal
# batsman_runs           1607
# Name: 62, dtype: object
# batter          JM Bairstow
# batsman_runs           1589
# Name: 63, dtype: object
# batter          DJ Bravo
# batsman_runs        1560
# Name: 64, dtype: object
# batter          D Padikkal
# batsman_runs          1559
# Name: 65, dtype: object
# batter          NV Ojha
# batsman_runs       1554
# Name: 66, dtype: object
# batter          SP Narine
# batsman_runs         1534
# Name: 67, dtype: object
# batter          S Dube
# batsman_runs      1502
# Name: 68, dtype: object
# batter          KK Nair
# batsman_runs       1496
# Name: 69, dtype: object
# batter          SS Tiwary
# batsman_runs         1494
# Name: 70, dtype: object
# batter          DJ Hooda
# batsman_runs        1466
# Name: 71, dtype: object
# batter          S Badrinath
# batsman_runs           1441
# Name: 72, dtype: object
# batter          EJG Morgan
# batsman_runs          1406
# Name: 73, dtype: object
# batter          BJ Hodge
# batsman_runs        1400
# Name: 74, dtype: object
# batter          Abhishek Sharma
# batsman_runs               1377
# Name: 75, dtype: object
# batter          SC Ganguly
# batsman_runs          1349
# Name: 76, dtype: object
# batter          CA Lynn
# batsman_runs       1329
# Name: 77, dtype: object
# batter          VR Iyer
# batsman_runs       1326
# Name: 78, dtype: object
# batter          DJ Hussey
# batsman_runs         1322
# Name: 79, dtype: object
# batter          SO Hetmyer
# batsman_runs          1243
# Name: 80, dtype: object
# batter          KM Jadhav
# batsman_runs         1208
# Name: 81, dtype: object
# batter          R Parag
# batsman_runs       1173
# Name: 82, dtype: object
# batter          MM Ali
# batsman_runs      1162
# Name: 83, dtype: object
# batter          Tilak Varma
# batsman_runs           1156
# Name: 84, dtype: object
# batter          TM Dilshan
# batsman_runs          1153
# Name: 85, dtype: object
# batter          IK Pathan
# batsman_runs         1150
# Name: 86, dtype: object
# batter          V Shankar
# batsman_runs         1115
# Name: 87, dtype: object
# batter          ML Hayden
# batsman_runs         1107
# Name: 88, dtype: object
# batter          M Vohra
# batsman_runs       1083
# Name: 89, dtype: object
# batter          LMP Simmons
# batsman_runs           1079
# Name: 90, dtype: object
# batter          B Sai Sudharsan
# batsman_runs               1034
# Name: 91, dtype: object
# batter          LRPL Taylor
# batsman_runs           1017
# Name: 92, dtype: object
# batter          R Tewatia
# batsman_runs         1013
# Name: 93, dtype: object
# batter          KP Pietersen
# batsman_runs            1001
# Name: 94, dtype: object
# batter          MC Henriques
# batsman_runs            1000
# Name: 95, dtype: object
# batter          AK Markram
# batsman_runs           995
# Name: 96, dtype: object
# batter          H Klaasen
# batsman_runs          993
# Name: 97, dtype: object
# batter          Y Venugopal Rao
# batsman_runs                985
# Name: 98, dtype: object
# batter          JA Morkel
# batsman_runs          975
# Name: 99, dtype: object
# batter          A Symonds
# batsman_runs          974
# Name: 100, dtype: object
# batter          CL White
# batsman_runs         971
# Name: 101, dtype: object
# batter          LS Livingstone
# batsman_runs               939
# Name: 102, dtype: object
# batter          BA Stokes
# batsman_runs          935
# Name: 103, dtype: object
# batter          DP Conway
# batsman_runs          924
# Name: 104, dtype: object
# batter          RK Singh
# batsman_runs         893
# Name: 105, dtype: object
# batter          HH Gibbs
# batsman_runs         886
# Name: 106, dtype: object
# batter          SM Curran
# batsman_runs          883
# Name: 107, dtype: object
# batter          STR Binny
# batsman_runs          880
# Name: 108, dtype: object
# batter          Harbhajan Singh
# batsman_runs                833
# Name: 109, dtype: object
# batter          R Ashwin
# batsman_runs         800
# Name: 110, dtype: object
# batter          RM Patidar
# batsman_runs           799
# Name: 111, dtype: object
# batter          MS Bisla
# batsman_runs         798
# Name: 112, dtype: object
# batter          Shakib Al Hasan
# batsman_runs                795
# Name: 113, dtype: object
# batter          TM Head
# batsman_runs        772
# Name: 114, dtype: object
# batter          ST Jayasuriya
# batsman_runs              768
# Name: 115, dtype: object
# batter          P Simran Singh
# batsman_runs               756
# Name: 116, dtype: object
# batter          GC Smith
# batsman_runs         739
# Name: 117, dtype: object
# batter          JM Sharma
# batsman_runs          730
# Name: 118, dtype: object
# batter          AD Mathews
# batsman_runs           724
# Name: 119, dtype: object
# batter          C Green
# batsman_runs        707
# Name: 120, dtype: object
# batter          TL Suman
# batsman_runs         676
# Name: 121, dtype: object
# batter          AM Nayar
# batsman_runs         672
# Name: 122, dtype: object
# batter          MR Marsh
# batsman_runs         665
# Name: 123, dtype: object
# batter          GJ Bailey
# batsman_runs          663
# Name: 124, dtype: object
# batter          TH David
# batsman_runs         659
# Name: 125, dtype: object
# batter          E Lewis
# batsman_runs        654
# Name: 126, dtype: object
# batter          PD Salt
# batsman_runs        653
# Name: 127, dtype: object
# batter          A Badoni
# batsman_runs         634
# Name: 128, dtype: object
# batter          PP Chawla
# batsman_runs          624
# Name: 129, dtype: object
# batter          CH Morris
# batsman_runs          618
# Name: 130, dtype: object
# batter          JJ Roy
# batsman_runs       614
# Name: 131, dtype: object
# batter          JD Ryder
# batsman_runs         604
# Name: 132, dtype: object
# batter          SN Khan
# batsman_runs        585
# Name: 133, dtype: object
# batter          Abdul Samad
# batsman_runs            579
# Name: 134, dtype: object
# batter          HM Amla
# batsman_runs        577
# Name: 135, dtype: object
# batter          M Shahrukh Khan
# batsman_runs                553
# Name: 136, dtype: object
# batter          Rashid Khan
# batsman_runs            545
# Name: 137, dtype: object
# batter          CJ Anderson
# batsman_runs            538
# Name: 138, dtype: object
# batter          Shahbaz Ahmed
# batsman_runs              536
# Name: 139, dtype: object
# batter          RS Bopara
# batsman_runs          531
# Name: 140, dtype: object
# batter          JP Faulkner
# batsman_runs            527
# Name: 141, dtype: object
# batter          MK Lomror
# batsman_runs          527
# Name: 142, dtype: object
# batter          PJ Cummins
# batsman_runs           515
# Name: 143, dtype: object
# batter          M Manhas
# batsman_runs         514
# Name: 144, dtype: object
# batter          Gurkeerat Singh
# batsman_runs                511
# Name: 145, dtype: object
# batter          OA Shah
# batsman_runs        506
# Name: 146, dtype: object
# batter          PC Valthaty
# batsman_runs            505
# Name: 147, dtype: object
# batter          SW Billings
# batsman_runs            503
# Name: 148, dtype: object
# batter          RR Rossouw
# batsman_runs           473
# Name: 149, dtype: object
# batter          DT Christian
# batsman_runs             460
# Name: 150, dtype: object
# batter          NLTC Perera
# batsman_runs            424
# Name: 151, dtype: object
# batter          SA Asnodkar
# batsman_runs            423
# Name: 152, dtype: object
# batter          Shashank Singh
# batsman_runs               423
# Name: 153, dtype: object
# batter          JR Hopes
# batsman_runs         417
# Name: 154, dtype: object
# batter          J Botha
# batsman_runs        409
# Name: 155, dtype: object
# batter          T Stubbs
# batsman_runs         405
# Name: 156, dtype: object
# batter          LR Shukla
# batsman_runs          405
# Name: 157, dtype: object
# batter          AL Menaria
# batsman_runs           401
# Name: 158, dtype: object
# batter          MV Boucher
# batsman_runs           394
# Name: 159, dtype: object
# batter          CA Pujara
# batsman_runs          390
# Name: 160, dtype: object
# batter          Azhar Mahmood
# batsman_runs              388
# Name: 161, dtype: object
# batter          A Mishra
# batsman_runs         381
# Name: 162, dtype: object
# batter          KR Mayers
# batsman_runs          379
# Name: 163, dtype: object
# batter          Washington Sundar
# batsman_runs                  378
# Name: 164, dtype: object
# batter          DB Ravi Teja
# batsman_runs             375
# Name: 165, dtype: object
# batter          S Sohal
# batsman_runs        368
# Name: 166, dtype: object
# batter          P Negi
# batsman_runs       365
# Name: 167, dtype: object
# batter          Abishek Porel
# batsman_runs              360
# Name: 168, dtype: object
# batter          R Powell
# batsman_runs         360
# Name: 169, dtype: object
# batter          DJ Mitchell
# batsman_runs            351
# Name: 170, dtype: object
# batter          KV Sharma
# batsman_runs          351
# Name: 171, dtype: object
# batter          N Wadhera
# batsman_runs          350
# Name: 172, dtype: object
# batter          Dhruv Jurel
# batsman_runs            347
# Name: 173, dtype: object
# batter          R Bhatia
# batsman_runs         342
# Name: 174, dtype: object
# batter          P Kumar
# batsman_runs        340
# Name: 175, dtype: object
# batter          AP Tare
# batsman_runs        339
# Name: 176, dtype: object
# batter          J Fraser-McGurk
# batsman_runs                330
# Name: 177, dtype: object
# batter          JEC Franklin
# batsman_runs             327
# Name: 178, dtype: object
# batter          RN ten Doeschate
# batsman_runs                 326
# Name: 179, dtype: object
# batter          Anuj Rawat
# batsman_runs           318
# Name: 180, dtype: object
# batter          R Vinay Kumar
# batsman_runs              310
# Name: 181, dtype: object
# batter          SN Thakur
# batsman_runs          307
# Name: 182, dtype: object
# batter          B Kumar
# batsman_runs        306
# Name: 183, dtype: object
# batter          Lalit Yadav
# batsman_runs            305
# Name: 184, dtype: object
# batter          DB Das
# batsman_runs       304
# Name: 185, dtype: object
# batter          C de Grandhomme
# batsman_runs                303
# Name: 186, dtype: object
# batter          Nithish Kumar Reddy
# batsman_runs                    303
# Name: 187, dtype: object
# batter          LA Pomersbach
# batsman_runs              302
# Name: 188, dtype: object
# batter          UBT Chand
# batsman_runs          300
# Name: 189, dtype: object
# batter          DJG Sammy
# batsman_runs          295
# Name: 190, dtype: object
# batter          SP Goswami
# batsman_runs           293
# Name: 191, dtype: object
# batter          Rahmanullah Gurbaz
# batsman_runs                   289
# Name: 192, dtype: object
# batter          Y Nagar
# batsman_runs        285
# Name: 193, dtype: object
# batter          GH Vihari
# batsman_runs          284
# Name: 194, dtype: object
# batter          VVS Laxman
# batsman_runs           282
# Name: 195, dtype: object
# batter          B Chipli
# batsman_runs         280
# Name: 196, dtype: object
# batter          A Ashish Reddy
# batsman_runs               280
# Name: 197, dtype: object
# batter          MJ Lumb
# batsman_runs        278
# Name: 198, dtype: object
# batter          PBB Rajapaksa
# batsman_runs              277
# Name: 199, dtype: object
# batter          PK Garg
# batsman_runs        273
# Name: 200, dtype: object
# batter          MJ Guptill
# batsman_runs           271
# Name: 201, dtype: object
# batter          R Sathish
# batsman_runs          270
# Name: 202, dtype: object
# batter          JO Holder
# batsman_runs          259
# Name: 203, dtype: object
# batter          M Kaif
# batsman_runs       259
# Name: 204, dtype: object
# batter          HV Patel
# batsman_runs         249
# Name: 205, dtype: object
# batter          Atharva Taide
# batsman_runs              247
# Name: 206, dtype: object
# batter          K Gowtham
# batsman_runs          247
# Name: 207, dtype: object
# batter          SM Katich
# batsman_runs          241
# Name: 208, dtype: object
# batter          BCJ Cutting
# batsman_runs            238
# Name: 209, dtype: object
# batter          MD Mishra
# batsman_runs          237
# Name: 210, dtype: object
# batter          Harpreet Brar
# batsman_runs              233
# Name: 211, dtype: object
# batter          A Manohar
# batsman_runs          231
# Name: 212, dtype: object
# batter          D Brevis
# batsman_runs         230
# Name: 213, dtype: object
# batter          WG Jacks
# batsman_runs         230
# Name: 214, dtype: object
# batter          R Ravindra
# batsman_runs           222
# Name: 215, dtype: object
# batter          Mohammad Nabi
# batsman_runs              221
# Name: 216, dtype: object
# batter          K Goel
# batsman_runs       218
# Name: 217, dtype: object
# batter          AA Jhunjhunwala
# batsman_runs                217
# Name: 218, dtype: object
# batter          R Dhawan
# batsman_runs         210
# Name: 219, dtype: object
# batter          UT Yadav
# batsman_runs         208
# Name: 220, dtype: object
# batter          K Rabada
# batsman_runs         206
# Name: 221, dtype: object
# batter          CA Ingram
# batsman_runs          205
# Name: 222, dtype: object
# batter          PD Collingwood
# batsman_runs               203
# Name: 223, dtype: object
# batter          JC Archer
# batsman_runs          199
# Name: 224, dtype: object
# batter          KS Bharat
# batsman_runs          199
# Name: 225, dtype: object
# batter          SK Warne
# batsman_runs         198
# Name: 226, dtype: object
# batter          JD Unadkat
# batsman_runs           197
# Name: 227, dtype: object
# batter          SP Fleming
# batsman_runs           196
# Name: 228, dtype: object
# batter          AS Raut
# batsman_runs        194
# Name: 229, dtype: object
# batter          BJ Rohrer
# batsman_runs          193
# Name: 230, dtype: object
# batter          Salman Butt
# batsman_runs            193
# Name: 231, dtype: object
# batter          YV Takawale
# batsman_runs            192
# Name: 232, dtype: object
# batter          HC Brook
# batsman_runs         190
# Name: 233, dtype: object
# batter          Ashutosh Sharma
# batsman_runs                189
# Name: 234, dtype: object
# batter          Bipul Sharma
# batsman_runs             187
# Name: 235, dtype: object
# batter          Kuldeep Yadav
# batsman_runs              183
# Name: 236, dtype: object
# batter          SD Hope
# batsman_runs        183
# Name: 237, dtype: object
# batter          MS Wade
# batsman_runs        183
# Name: 238, dtype: object
# batter          FY Fazal
# batsman_runs         183
# Name: 239, dtype: object
# batter          Sikandar Raza
# batsman_runs              182
# Name: 240, dtype: object
# batter          CR Brathwaite
# batsman_runs              181
# Name: 241, dtype: object
# batter          AC Voges
# batsman_runs         181
# Name: 242, dtype: object
# batter          S Gopal
# batsman_runs        180
# Name: 243, dtype: object
# batter          AB Agarkar
# batsman_runs           179
# Name: 244, dtype: object
# batter          MF Maharoof
# batsman_runs            177
# Name: 245, dtype: object
# batter          C Munro
# batsman_runs        177
# Name: 246, dtype: object
# batter          DH Yagnik
# batsman_runs          170
# Name: 247, dtype: object
# batter          Ramandeep Singh
# batsman_runs                170
# Name: 248, dtype: object
# batter          CM Gautam
# batsman_runs          169
# Name: 249, dtype: object
# batter          MG Johnson
# batsman_runs           167
# Name: 250, dtype: object
# batter          DW Steyn
# batsman_runs         167
# Name: 251, dtype: object
# batter          MN van Wyk
# batsman_runs           167
# Name: 252, dtype: object
# batter          PA Reddy
# batsman_runs         164
# Name: 253, dtype: object
# batter          A Raghuvanshi
# batsman_runs              163
# Name: 254, dtype: object
# batter          N Jagadeesan
# batsman_runs             162
# Name: 255, dtype: object
# batter          MN Samuels
# batsman_runs           161
# Name: 256, dtype: object
# batter          RE van der Merwe
# batsman_runs                 159
# Name: 257, dtype: object
# batter          R McLaren
# batsman_runs          159
# Name: 258, dtype: object
# batter          AD Hales
# batsman_runs         148
# Name: 259, dtype: object
# batter          D Wiese
# batsman_runs        148
# Name: 260, dtype: object
# batter          SM Pollock
# batsman_runs           147
# Name: 261, dtype: object
# batter          S Vidyut
# batsman_runs         145
# Name: 262, dtype: object
# batter          Sachin Baby
# batsman_runs            144
# Name: 263, dtype: object
# batter          N Saini
# batsman_runs        140
# Name: 264, dtype: object
# batter          Naman Dhir
# batsman_runs           140
# Name: 265, dtype: object
# batter          Anmolpreet Singh
# batsman_runs                 139
# Name: 266, dtype: object
# batter          S Anirudha
# batsman_runs           136
# Name: 267, dtype: object
# batter          SB Styris
# batsman_runs          131
# Name: 268, dtype: object
# batter          W Jaffer
# batsman_runs         130
# Name: 269, dtype: object
# batter          RD Chahar
# batsman_runs          129
# Name: 270, dtype: object
# batter          Kamran Akmal
# batsman_runs             128
# Name: 271, dtype: object
# batter          UT Khawaja
# batsman_runs           127
# Name: 272, dtype: object
# batter          P Dogra
# batsman_runs        127
# Name: 273, dtype: object
# batter          TK Curran
# batsman_runs          127
# Name: 274, dtype: object
# batter          SS Prabhudessai
# batsman_runs                126
# Name: 275, dtype: object
# batter          M Morkel
# batsman_runs         126
# Name: 276, dtype: object
# batter          MC Juneja
# batsman_runs          125
# Name: 277, dtype: object
# batter          BB Samantray
# batsman_runs             125
# Name: 278, dtype: object
# batter          MM Sharma
# batsman_runs          124
# Name: 279, dtype: object
# batter          B Lee
# batsman_runs      124
# Name: 280, dtype: object
# batter          Harpreet Singh
# batsman_runs               123
# Name: 281, dtype: object
# batter          AB McDonald
# batsman_runs            123
# Name: 282, dtype: object
# batter          DL Vettori
# batsman_runs           121
# Name: 283, dtype: object
# batter          NK Patel
# batsman_runs         121
# Name: 284, dtype: object
# batter          TG Southee
# batsman_runs           120
# Name: 285, dtype: object
# batter          AC Blizzard
# batsman_runs            120
# Name: 286, dtype: object
# batter          Z Khan
# batsman_runs       117
# Name: 287, dtype: object
# batter          Misbah-ul-Haq
# batsman_runs              117
# Name: 288, dtype: object
# batter          RJ Harris
# batsman_runs          117
# Name: 289, dtype: object
# batter          MW Short
# batsman_runs         117
# Name: 290, dtype: object
# batter          KK Cooper
# batsman_runs          116
# Name: 291, dtype: object
# batter          DJM Short
# batsman_runs          115
# Name: 292, dtype: object
# batter          R Shepherd
# batsman_runs           115
# Name: 293, dtype: object
# batter          Aman Hakim Khan
# batsman_runs                115
# Name: 294, dtype: object
# batter          M Kartik
# batsman_runs         113
# Name: 295, dtype: object
# batter          DJ Harris
# batsman_runs          111
# Name: 296, dtype: object
# batter          Mohammed Siraj
# batsman_runs               109
# Name: 297, dtype: object
# batter          LJ Wright
# batsman_runs          106
# Name: 298, dtype: object
# batter          JDP Oram
# batsman_runs         106
# Name: 299, dtype: object
# batter          SE Rutherford
# batsman_runs              106
# Name: 300, dtype: object
# batter          MA Starc
# batsman_runs         105
# Name: 301, dtype: object
# batter          DS Kulkarni
# batsman_runs            104
# Name: 302, dtype: object
# batter          RJ Quiney
# batsman_runs          103
# Name: 303, dtype: object
# batter          MS Gony
# batsman_runs         99
# Name: 304, dtype: object
# batter          SD Chitnis
# batsman_runs            99
# Name: 305, dtype: object
# batter          MJ Clarke
# batsman_runs           98
# Name: 306, dtype: object
# batter          CJ Ferguson
# batsman_runs             98
# Name: 307, dtype: object
# batter          PN Mankad
# batsman_runs           97
# Name: 308, dtype: object
# batter          Arshad Khan
# batsman_runs             96
# Name: 309, dtype: object
# batter          JDS Neesham
# batsman_runs             92
# Name: 310, dtype: object
# batter          PR Shah
# batsman_runs         92
# Name: 311, dtype: object
# batter          DJ Jacobs
# batsman_runs           92
# Name: 312, dtype: object
# batter          RT Ponting
# batsman_runs            91
# Name: 313, dtype: object
# batter          S Rana
# batsman_runs        91
# Name: 314, dtype: object
# batter          AJ Tye
# batsman_runs        91
# Name: 315, dtype: object
# batter          AD Nath
# batsman_runs         90
# Name: 316, dtype: object
# batter          SL Malinga
# batsman_runs            88
# Name: 317, dtype: object
# batter          Iqbal Abdulla
# batsman_runs               88
# Name: 318, dtype: object
# batter          AP Majumdar
# batsman_runs             87
# Name: 319, dtype: object
# batter          Ankit Sharma
# batsman_runs              87
# Name: 320, dtype: object
# batter          MJ McClenaghan
# batsman_runs                85
# Name: 321, dtype: object
# batter          TA Boult
# batsman_runs          83
# Name: 322, dtype: object
# batter          RE Levi
# batsman_runs         83
# Name: 323, dtype: object
# batter          NM Coulter-Nile
# batsman_runs                 82
# Name: 324, dtype: object
# batter          LA Carseldine
# batsman_runs               81
# Name: 325, dtype: object
# batter          Shahid Afridi
# batsman_runs               81
# Name: 326, dtype: object
# batter          WPUJC Vaas
# batsman_runs            81
# Name: 327, dtype: object
# batter          CJ Jordan
# batsman_runs           81
# Name: 328, dtype: object
# batter          DL Chahar
# batsman_runs           80
# Name: 329, dtype: object
# batter          RV Patel
# batsman_runs          80
# Name: 330, dtype: object
# batter          AD Mascarenhas
# batsman_runs                79
# Name: 331, dtype: object
# batter          JR Philippe
# batsman_runs             78
# Name: 332, dtype: object
# batter          CR Woakes
# batsman_runs           78
# Name: 333, dtype: object
# batter          B Akhil
# batsman_runs         76
# Name: 334, dtype: object
# batter          IR Jaggi
# batsman_runs          76
# Name: 335, dtype: object
# batter          TR Birt
# batsman_runs         75
# Name: 336, dtype: object
# batter          Mohammed Shami
# batsman_runs                74
# Name: 337, dtype: object
# batter          RR Sarwan
# batsman_runs           73
# Name: 338, dtype: object
# batter          M Klinger
# batsman_runs           73
# Name: 339, dtype: object
# batter          PWH de Silva
# batsman_runs              72
# Name: 340, dtype: object
# batter          MJ Santner
# batsman_runs            70
# Name: 341, dtype: object
# batter          J Suchith
# batsman_runs           70
# Name: 342, dtype: object
# batter          AA Bilakhia
# batsman_runs             69
# Name: 343, dtype: object
# batter          Vivrant Sharma
# batsman_runs                69
# Name: 344, dtype: object
# batter          LH Ferguson
# batsman_runs             68
# Name: 345, dtype: object
# batter          JJ Bumrah
# batsman_runs           68
# Name: 346, dtype: object
# batter          RR Powar
# batsman_runs          67
# Name: 347, dtype: object
# batter          HR Shokeen
# batsman_runs            66
# Name: 348, dtype: object
# batter          R Sharma
# batsman_runs          66
# Name: 349, dtype: object
# batter          M Jansen
# batsman_runs          66
# Name: 350, dtype: object
# batter          WD Parnell
# batsman_runs            65
# Name: 351, dtype: object
# batter          KA Jamieson
# batsman_runs             65
# Name: 352, dtype: object
# batter          GD Phillips
# batsman_runs             65
# Name: 353, dtype: object
# batter          Mohammad Hafeez
# batsman_runs                 64
# Name: 354, dtype: object
# batter          Anirudh Singh
# batsman_runs               63
# Name: 355, dtype: object
# batter          A Flintoff
# batsman_runs            62
# Name: 356, dtype: object
# batter          SP Jackson
# batsman_runs            61
# Name: 357, dtype: object
# batter          S Aravind
# batsman_runs           59
# Name: 358, dtype: object
# batter          MG Bracewell
# batsman_runs              58
# Name: 359, dtype: object
# batter          I Sharma
# batsman_runs          57
# Name: 360, dtype: object
# batter          Vishnu Vinod
# batsman_runs              56
# Name: 361, dtype: object
# batter          WA Mota
# batsman_runs         56
# Name: 362, dtype: object
# batter          M Rawat
# batsman_runs         55
# Name: 363, dtype: object
# batter          Sandeep Sharma
# batsman_runs                54
# Name: 364, dtype: object
# batter          DJ Willey
# batsman_runs           53
# Name: 365, dtype: object
# batter          A Chopra
# batsman_runs          53
# Name: 366, dtype: object
# batter          Shoaib Malik
# batsman_runs              52
# Name: 367, dtype: object
# batter          RP Singh
# batsman_runs          52
# Name: 368, dtype: object
# batter          OF Smith
# batsman_runs          51
# Name: 369, dtype: object
# batter          R Rampaul
# batsman_runs           51
# Name: 370, dtype: object
# batter          Sameer Rizvi
# batsman_runs              51
# Name: 371, dtype: object
# batter          KB Arun Karthik
# batsman_runs                 51
# Name: 372, dtype: object
# batter          Swapnil Singh
# batsman_runs               51
# Name: 373, dtype: object
# batter          Shivam Mavi
# batsman_runs             51
# Name: 374, dtype: object
# batter          VR Aaron
# batsman_runs          50
# Name: 375, dtype: object
# batter          RV Gomez
# batsman_runs          50
# Name: 376, dtype: object
# batter          SB Bangar
# batsman_runs           49
# Name: 377, dtype: object
# batter          AG Paunikar
# batsman_runs             49
# Name: 378, dtype: object
# batter          AS Yadav
# batsman_runs          49
# Name: 379, dtype: object
# batter          A Nortje
# batsman_runs          49
# Name: 380, dtype: object
# batter          T Kohler-Cadmore
# batsman_runs                  48
# Name: 381, dtype: object
# batter          M Markande
# batsman_runs            48
# Name: 382, dtype: object
# batter          Yashpal Singh
# batsman_runs               47
# Name: 383, dtype: object
# batter          D Pretorius
# batsman_runs             44
# Name: 384, dtype: object
# batter          DR Sams
# batsman_runs         44
# Name: 385, dtype: object
# batter          Sunny Singh
# batsman_runs             43
# Name: 386, dtype: object
# batter          PVD Chameera
# batsman_runs              43
# Name: 387, dtype: object
# batter          AB Barath
# batsman_runs           42
# Name: 388, dtype: object
# batter          Azmatullah Omarzai
# batsman_runs                    42
# Name: 389, dtype: object
# batter          SK Trivedi
# batsman_runs            42
# Name: 390, dtype: object
# batter          A Nehra
# batsman_runs         41
# Name: 391, dtype: object
# batter          Avesh Khan
# batsman_runs            41
# Name: 392, dtype: object
# batter          BR Dunk
# batsman_runs         40
# Name: 393, dtype: object
# batter          J Yadav
# batsman_runs         40
# Name: 394, dtype: object
# batter          Rasikh Salam
# batsman_runs              40
# Name: 395, dtype: object
# batter          LPC Silva
# batsman_runs           40
# Name: 396, dtype: object
# batter          DJ Thornely
# batsman_runs             39
# Name: 397, dtype: object
# batter          Umar Gul
# batsman_runs          39
# Name: 398, dtype: object
# batter          AUK Pathan
# batsman_runs            39
# Name: 399, dtype: object
# batter          MM Patel
# batsman_runs          39
# Name: 400, dtype: object
# batter          S Nadeem
# batsman_runs          39
# Name: 401, dtype: object
# batter          YS Chahal
# batsman_runs           37
# Name: 402, dtype: object
# batter          S Narwal
# batsman_runs          37
# Name: 403, dtype: object
# batter          Sohail Tanvir
# batsman_runs               36
# Name: 404, dtype: object
# batter          Joginder Sharma
# batsman_runs                 36
# Name: 405, dtype: object
# batter          L Balaji
# batsman_runs          36
# Name: 406, dtype: object
# batter          KW Richardson
# batsman_runs               36
# Name: 407, dtype: object
# batter          AN Ahmed
# batsman_runs          36
# Name: 408, dtype: object
# batter          Anureet Singh
# batsman_runs               36
# Name: 409, dtype: object
# batter          M Ashwin
# batsman_runs          35
# Name: 410, dtype: object
# batter          B Sumanth
# batsman_runs           35
# Name: 411, dtype: object
# batter          A Kumble
# batsman_runs          35
# Name: 412, dtype: object
# batter          L Ronchi
# batsman_runs          34
# Name: 413, dtype: object
# batter          S Sreesanth
# batsman_runs             34
# Name: 414, dtype: object
# batter          AP Dole
# batsman_runs         34
# Name: 415, dtype: object
# batter          A Mithun
# batsman_runs          34
# Name: 416, dtype: object
# batter          Imran Tahir
# batsman_runs             33
# Name: 417, dtype: object
# batter          Navdeep Saini
# batsman_runs               33
# Name: 418, dtype: object
# batter          D Salunkhe
# batsman_runs            33
# Name: 419, dtype: object
# batter          SB Dubey
# batsman_runs          33
# Name: 420, dtype: object
# batter          Basil Thampi
# batsman_runs              32
# Name: 421, dtype: object
# batter          AT Carey
# batsman_runs          32
# Name: 422, dtype: object
# batter          RJ Peterson
# batsman_runs             32
# Name: 423, dtype: object
# batter          Ravi Bishnoi
# batsman_runs              32
# Name: 424, dtype: object
# batter          NS Naik
# batsman_runs         31
# Name: 425, dtype: object
# batter          S Sriram
# batsman_runs          31
# Name: 426, dtype: object
# batter          T Taibu
# batsman_runs         31
# Name: 427, dtype: object
# batter          J Syed Mohammad
# batsman_runs                 29
# Name: 428, dtype: object
# batter          Arshdeep Singh
# batsman_runs                29
# Name: 429, dtype: object
# batter          VH Zol
# batsman_runs        29
# Name: 430, dtype: object
# batter          SB Jakati
# batsman_runs           28
# Name: 431, dtype: object
# batter          AS Joseph
# batsman_runs           27
# Name: 432, dtype: object
# batter          PJ Sangwan
# batsman_runs            26
# Name: 433, dtype: object
# batter          AB Dinda
# batsman_runs          26
# Name: 434, dtype: object
# batter          NL McCullum
# batsman_runs             26
# Name: 435, dtype: object
# batter          TL Seifert
# batsman_runs            26
# Name: 436, dtype: object
# batter          JM Kemp
# batsman_runs         26
# Name: 437, dtype: object
# batter          DJ Malan
# batsman_runs          26
# Name: 438, dtype: object
# batter          AS Rajpoot
# batsman_runs            26
# Name: 439, dtype: object
# batter          AS Roy
# batsman_runs        26
# Name: 440, dtype: object
# batter          MD Shanaka
# batsman_runs            26
# Name: 441, dtype: object
# batter          Mohsin Khan
# batsman_runs             25
# Name: 442, dtype: object
# batter          CV Varun
# batsman_runs          25
# Name: 443, dtype: object
# batter          S Chanderpaul
# batsman_runs               25
# Name: 444, dtype: object
# batter          A Choudhary
# batsman_runs             25
# Name: 445, dtype: object
# batter          Sanvir Singh
# batsman_runs              25
# Name: 446, dtype: object
# batter          ER Dwivedi
# batsman_runs            24
# Name: 447, dtype: object
# batter          Tanush Kotian
# batsman_runs               24
# Name: 448, dtype: object
# batter          AJ Turner
# batsman_runs           24
# Name: 449, dtype: object
# batter          KC Cariappa
# batsman_runs             24
# Name: 450, dtype: object
# batter          MA Khote
# batsman_runs          24
# Name: 451, dtype: object
# batter          Umran Malik
# batsman_runs             23
# Name: 452, dtype: object
# batter          P Dubey
# batsman_runs         23
# Name: 453, dtype: object
# batter          AF Milne
# batsman_runs          23
# Name: 454, dtype: object
# batter          J Arunkumar
# batsman_runs             23
# Name: 455, dtype: object
# batter          BMAJ Mendis
# batsman_runs             23
# Name: 456, dtype: object
# batter          SW Tait
# batsman_runs         23
# Name: 457, dtype: object
# batter          SA Abbott
# batsman_runs           22
# Name: 458, dtype: object
# batter          HE van der Dussen
# batsman_runs                   22
# Name: 459, dtype: object
# batter          AU Rashid
# batsman_runs           22
# Name: 460, dtype: object
# batter          GB Hogg
# batsman_runs         22
# Name: 461, dtype: object
# batter          KL Nagarkoti
# batsman_runs              22
# Name: 462, dtype: object
# batter          Yudhvir Singh
# batsman_runs               22
# Name: 463, dtype: object
# batter          TU Deshpande
# batsman_runs              21
# Name: 464, dtype: object
# batter          DE Bollinger
# batsman_runs              21
# Name: 465, dtype: object
# batter          B Indrajith
# batsman_runs             21
# Name: 466, dtype: object
# batter          C Sakariya
# batsman_runs            20
# Name: 467, dtype: object
# batter          AC Thomas
# batsman_runs           20
# Name: 468, dtype: object
# batter          NJ Maddinson
# batsman_runs              20
# Name: 469, dtype: object
# batter          M Muralitharan
# batsman_runs                20
# Name: 470, dtype: object
# batter          S Kaul
# batsman_runs        20
# Name: 471, dtype: object
# batter          RR Raje
# batsman_runs         20
# Name: 472, dtype: object
# batter          NT Ellis
# batsman_runs          19
# Name: 473, dtype: object
# batter          Gulbadin Naib
# batsman_runs               19
# Name: 474, dtype: object
# batter          P Ray Barman
# batsman_runs              19
# Name: 475, dtype: object
# batter          Y Gnaneswara Rao
# batsman_runs                  19
# Name: 476, dtype: object
# batter          Akash Deep
# batsman_runs            19
# Name: 477, dtype: object
# batter          R Shukla
# batsman_runs          19
# Name: 478, dtype: object
# batter          R Bishnoi
# batsman_runs           19
# Name: 479, dtype: object
# batter          DR Martyn
# batsman_runs           19
# Name: 480, dtype: object
# batter          P Sahu
# batsman_runs        19
# Name: 481, dtype: object
# batter          JR Hazlewood
# batsman_runs              19
# Name: 482, dtype: object
# batter          A Mukund
# batsman_runs          19
# Name: 483, dtype: object
# batter          Harmeet Singh
# batsman_runs               18
# Name: 484, dtype: object
# batter          Naveen-ul-Haq
# batsman_runs               18
# Name: 485, dtype: object
# batter          DS Lehmann
# batsman_runs            18
# Name: 486, dtype: object
# batter          PV Tambe
# batsman_runs          18
# Name: 487, dtype: object
# batter          Saurav Chauhan
# batsman_runs                18
# Name: 488, dtype: object
# batter          JJ van der Wath
# batsman_runs                 18
# Name: 489, dtype: object
# batter          KMA Paul
# batsman_runs          18
# Name: 490, dtype: object
# batter          T Banton
# batsman_runs          18
# Name: 491, dtype: object
# batter          Sumit Kumar
# batsman_runs             18
# Name: 492, dtype: object
# batter          BJ Haddin
# batsman_runs           18
# Name: 493, dtype: object
# batter          Parvez Rasool
# batsman_runs               17
# Name: 494, dtype: object
# batter          JA Richardson
# batsman_runs               17
# Name: 495, dtype: object
# batter          YV Dhull
# batsman_runs          16
# Name: 496, dtype: object
# batter          AJ Hosein
# batsman_runs           16
# Name: 497, dtype: object
# batter          CK Kapugedera
# batsman_runs               16
# Name: 498, dtype: object
# batter          KS Sharma
# batsman_runs           16
# Name: 499, dtype: object
# batter          PP Ojha
# batsman_runs         16
# Name: 500, dtype: object
# batter          VY Mahesh
# batsman_runs           15
# Name: 501, dtype: object
# batter          GR Napier
# batsman_runs           15
# Name: 502, dtype: object
# batter          SD Lad
# batsman_runs        15
# Name: 503, dtype: object
# batter          JL Pattinson
# batsman_runs              15
# Name: 504, dtype: object
# batter          A Zampa
# batsman_runs         15
# Name: 505, dtype: object
# batter          I Udana
# batsman_runs         15
# Name: 506, dtype: object
# batter          Virat Singh
# batsman_runs             15
# Name: 507, dtype: object
# batter          C Madan
# batsman_runs         15
# Name: 508, dtype: object
# batter          Vijaykumar Vyshak
# batsman_runs                   14
# Name: 509, dtype: object
# batter          F Behardien
# batsman_runs             14
# Name: 510, dtype: object
# batter          MDKJ Perera
# batsman_runs             14
# Name: 511, dtype: object
# batter          FA Allen
# batsman_runs          14
# Name: 512, dtype: object
# batter          G Coetzee
# batsman_runs           14
# Name: 513, dtype: object
# batter          Kartik Tyagi
# batsman_runs              13
# Name: 514, dtype: object
# batter          R Sai Kishore
# batsman_runs               13
# Name: 515, dtype: object
# batter          DT Patil
# batsman_runs          13
# Name: 516, dtype: object
# batter          Arjun Tendulkar
# batsman_runs                 13
# Name: 517, dtype: object
# batter          S Badree
# batsman_runs          13
# Name: 518, dtype: object
# batter          KJ Abbott
# batsman_runs           13
# Name: 519, dtype: object
# batter          Mustafizur Rahman
# batsman_runs                   13
# Name: 520, dtype: object
# batter          DR Shorey
# batsman_runs           13
# Name: 521, dtype: object
# batter          Noor Ahmad
# batsman_runs            13
# Name: 522, dtype: object
# batter          T Thushara
# batsman_runs            12
# Name: 523, dtype: object
# batter          MA Wood
# batsman_runs         12
# Name: 524, dtype: object
# batter          Mujeeb Ur Rahman
# batsman_runs                  12
# Name: 525, dtype: object
# batter          AA Chavan
# batsman_runs           12
# Name: 526, dtype: object
# batter          AR Bawne
# batsman_runs          12
# Name: 527, dtype: object
# batter          DAJ Bracewell
# batsman_runs               12
# Name: 528, dtype: object
# batter          K Upadhyay
# batsman_runs            12
# Name: 529, dtype: object
# batter          DG Nalkande
# batsman_runs             12
# Name: 530, dtype: object
# batter          Karanveer Singh
# batsman_runs                 12
# Name: 531, dtype: object
# batter          RA Bawa
# batsman_runs         11
# Name: 532, dtype: object
# batter          M Ntini
# batsman_runs         11
# Name: 533, dtype: object
# batter          T Henderson
# batsman_runs             11
# Name: 534, dtype: object
# batter          T Kohli
# batsman_runs         11
# Name: 535, dtype: object
# batter          DNT Zoysa
# batsman_runs           11
# Name: 536, dtype: object
# batter          TD Paine
# batsman_runs          10
# Name: 537, dtype: object
# batter          SMSM Senanayake
# batsman_runs                 10
# Name: 538, dtype: object
# batter          X Thalaivan Sargunam
# batsman_runs                      10
# Name: 539, dtype: object
# batter          KAJ Roach
# batsman_runs           10
# Name: 540, dtype: object
# batter          Mukesh Kumar
# batsman_runs              10
# Name: 541, dtype: object
# batter          AG Murtaza
# batsman_runs            10
# Name: 542, dtype: object
# batter          JE Root
# batsman_runs         10
# Name: 543, dtype: object
# batter          J Theron
# batsman_runs          10
# Name: 544, dtype: object
# batter          RK Bhui
# batsman_runs         10
# Name: 545, dtype: object
# batter          BB Sran
# batsman_runs         10
# Name: 546, dtype: object
# batter          D du Preez
# batsman_runs            10
# Name: 547, dtype: object
# batter          AA Noffke
# batsman_runs            9
# Name: 548, dtype: object
# batter          AA Kulkarni
# batsman_runs              9
# Name: 549, dtype: object
# batter          L Wood
# batsman_runs         9
# Name: 550, dtype: object
# batter          SM Harwood
# batsman_runs             9
# Name: 551, dtype: object
# batter          M Prasidh Krishna
# batsman_runs                    9
# Name: 552, dtype: object
# batter          K Kartikeya
# batsman_runs              9
# Name: 553, dtype: object
# batter          VG Arora
# batsman_runs           9
# Name: 554, dtype: object
# batter          TS Mills
# batsman_runs           8
# Name: 555, dtype: object
# batter          TM Srivastava
# batsman_runs                8
# Name: 556, dtype: object
# batter          P Chopra
# batsman_runs           8
# Name: 557, dtype: object
# batter          Jaskaran Singh
# batsman_runs                 8
# Name: 558, dtype: object
# batter          OC McCoy
# batsman_runs           8
# Name: 559, dtype: object
# batter          CJ McKay
# batsman_runs           8
# Name: 560, dtype: object
# batter          JPR Scantlebury-Searles
# batsman_runs                          8
# Name: 561, dtype: object
# batter          CK Langeveldt
# batsman_runs                8
# Name: 562, dtype: object
# batter          D Ferreira
# batsman_runs             8
# Name: 563, dtype: object
# batter          UA Birla
# batsman_runs           7
# Name: 564, dtype: object
# batter          Simarjeet Singh
# batsman_runs                  7
# Name: 565, dtype: object
# batter          Pankaj Singh
# batsman_runs               7
# Name: 566, dtype: object
# batter          M Theekshana
# batsman_runs               7
# Name: 567, dtype: object
# batter          AN Ghosh
# batsman_runs           7
# Name: 568, dtype: object
# batter          Ankit Soni
# batsman_runs             7
# Name: 569, dtype: object
# batter          I Malhotra
# batsman_runs             7
# Name: 570, dtype: object
# batter          IS Sodhi
# batsman_runs           7
# Name: 571, dtype: object
# batter          VS Malik
# batsman_runs           7
# Name: 572, dtype: object
# batter          V Viyaskanth
# batsman_runs               7
# Name: 573, dtype: object
# batter          SB Joshi
# batsman_runs           6
# Name: 574, dtype: object
# batter          SH Johnson
# batsman_runs             6
# Name: 575, dtype: object
# batter          SS Shaikh
# batsman_runs            6
# Name: 576, dtype: object
# batter          BA Bhatt
# batsman_runs           6
# Name: 577, dtype: object
# batter          JP Behrendorff
# batsman_runs                 6
# Name: 578, dtype: object
# batter          PSP Handscomb
# batsman_runs                6
# Name: 579, dtype: object
# batter          Mukesh Choudhary
# batsman_runs                   6
# Name: 580, dtype: object
# batter          DM Bravo
# batsman_runs           6
# Name: 581, dtype: object
# batter          B Laughlin
# batsman_runs             5
# Name: 582, dtype: object
# batter          Arshad Khan (2)
# batsman_runs                  5
# Name: 583, dtype: object
# batter          Shivam Sharma
# batsman_runs                5
# Name: 584, dtype: object
# batter          P Awana
# batsman_runs          5
# Name: 585, dtype: object
# batter          B Stanlake
# batsman_runs             5
# Name: 586, dtype: object
# batter          KMDN Kulasekara
# batsman_runs                  5
# Name: 587, dtype: object
# batter          SJ Srivastava
# batsman_runs                5
# Name: 588, dtype: object
# batter          Akash Madhwal
# batsman_runs                4
# Name: 589, dtype: object
# batter          GD McGrath
# batsman_runs             4
# Name: 590, dtype: object
# batter          A Chandila
# batsman_runs             4
# Name: 591, dtype: object
# batter          A Tomar
# batsman_runs          4
# Name: 592, dtype: object
# batter          DP Nannes
# batsman_runs            4
# Name: 593, dtype: object
# batter          RS Sodhi
# batsman_runs           4
# Name: 594, dtype: object
# batter          FH Edwards
# batsman_runs             4
# Name: 595, dtype: object
# batter          CRD Fernando
# batsman_runs               4
# Name: 596, dtype: object
# batter          Liton Das
# batsman_runs            4
# Name: 597, dtype: object
# batter          A Uniyal
# batsman_runs           4
# Name: 598, dtype: object
# batter          VRV Singh
# batsman_runs            4
# Name: 599, dtype: object
# batter          A Dananjaya
# batsman_runs              4
# Name: 600, dtype: object
# batter          GC Viljoen
# batsman_runs             3
# Name: 601, dtype: object
# batter          Fazalhaq Farooqi
# batsman_runs                   3
# Name: 602, dtype: object
# batter          Younis Khan
# batsman_runs              3
# Name: 603, dtype: object
# batter          T Natarajan
# batsman_runs              3
# Name: 604, dtype: object
# batter          BAW Mendis
# batsman_runs             3
# Name: 605, dtype: object
# batter          JE Taylor
# batsman_runs            3
# Name: 606, dtype: object
# batter          Kamran Khan
# batsman_runs              3
# Name: 607, dtype: object
# batter          S Tyagi
# batsman_runs          3
# Name: 608, dtype: object
# batter          Kumar Kushagra
# batsman_runs                 3
# Name: 609, dtype: object
# batter          R Ninan
# batsman_runs          3
# Name: 610, dtype: object
# batter          RJW Topley
# batsman_runs             3
# Name: 611, dtype: object
# batter          Mohammad Asif
# batsman_runs                3
# Name: 612, dtype: object
# batter          D Kalyankrishna
# batsman_runs                  3
# Name: 613, dtype: object
# batter          A Singh
# batsman_runs          2
# Name: 614, dtype: object
# batter          RJ Gleeson
# batsman_runs             2
# Name: 615, dtype: object
# batter          Mashrafe Mortaza
# batsman_runs                   2
# Name: 616, dtype: object
# batter          T Shamsi
# batsman_runs           2
# Name: 617, dtype: object
# batter          BR Sharath
# batsman_runs             2
# Name: 618, dtype: object
# batter          Mohammad Ashraful
# batsman_runs                    2
# Name: 619, dtype: object
# batter          RG More
# batsman_runs          2
# Name: 620, dtype: object
# batter          Shoaib Akhtar
# batsman_runs                2
# Name: 621, dtype: object
# batter          Shivam Singh
# batsman_runs               2
# Name: 622, dtype: object
# batter          GHS Garton
# batsman_runs             2
# Name: 623, dtype: object
# batter          H Das
# batsman_runs        2
# Name: 624, dtype: object
# batter          Harshit Rana
# batsman_runs               2
# Name: 625, dtype: object
# batter          A Kamboj
# batsman_runs           2
# Name: 626, dtype: object
# batter          VS Yeligati
# batsman_runs              2
# Name: 627, dtype: object
# batter          SB Wagh
# batsman_runs          2
# Name: 628, dtype: object
# batter          S Randiv
# batsman_runs           2
# Name: 629, dtype: object
# batter          RS Gavaskar
# batsman_runs              2
# Name: 630, dtype: object
# batter          KP Appanna
# batsman_runs             2
# Name: 631, dtype: object
# batter          PM Sarvesh Kumar
# batsman_runs                   1
# Name: 632, dtype: object
# batter          LB Williams
# batsman_runs              1
# Name: 633, dtype: object
# batter          LE Plunkett
# batsman_runs              1
# Name: 634, dtype: object
# batter          HF Gurney
# batsman_runs            1
# Name: 635, dtype: object
# batter          DJ Muthuswami
# batsman_runs                1
# Name: 636, dtype: object
# batter          Abdul Basith
# batsman_runs               1
# Name: 637, dtype: object
# batter          M de Lange
# batsman_runs             1
# Name: 638, dtype: object
# batter          Mohit Rathee
# batsman_runs               1
# Name: 639, dtype: object
# batter          SE Bond
# batsman_runs          1
# Name: 640, dtype: object
# batter          KA Maharaj
# batsman_runs             1
# Name: 641, dtype: object
# batter          KK Ahmed
# batsman_runs           1
# Name: 642, dtype: object
# batter          MJ Suthar
# batsman_runs            1
# Name: 643, dtype: object
# batter          Shoaib Ahmed
# batsman_runs               1
# Name: 644, dtype: object
# batter          SZ Mulani
# batsman_runs            1
# Name: 645, dtype: object
# batter          DP Vijaykumar
# batsman_runs                1
# Name: 646, dtype: object
# batter          BE Hendricks
# batsman_runs               1
# Name: 647, dtype: object
# batter          NJ Rimmington
# batsman_runs                1
# Name: 648, dtype: object
# batter          P Parameswaran
# batsman_runs                 1
# Name: 649, dtype: object
# batter          S Lamichhane
# batsman_runs               0
# Name: 650, dtype: object
# batter          Abdur Razzak
# batsman_runs               0
# Name: 651, dtype: object
# batter          IC Pandey
# batsman_runs            0
# Name: 652, dtype: object
# batter          L Ablish
# batsman_runs           0
# Name: 653, dtype: object
# batter          YA Abdulla
# batsman_runs             0
# Name: 654, dtype: object
# batter          Y Prithvi Raj
# batsman_runs                0
# Name: 655, dtype: object
# batter          U Kaul
# batsman_runs         0
# Name: 656, dtype: object
# batter          R Sanjay Yadav
# batsman_runs                 0
# Name: 657, dtype: object
# batter          RP Meredith
# batsman_runs              0
# Name: 658, dtype: object
# batter          RR Bhatkal
# batsman_runs             0
# Name: 659, dtype: object
# batter          S Kaushik
# batsman_runs            0
# Name: 660, dtype: object
# batter          K Yadav
# batsman_runs          0
# Name: 661, dtype: object
# batter          SS Cottrell
# batsman_runs              0
# Name: 662, dtype: object
# batter          S Ladda
# batsman_runs          0
# Name: 663, dtype: object
# batter          KR Sen
# batsman_runs         0
# Name: 664, dtype: object
# batter          Mayank Dagar
# batsman_runs               0
# Name: 665, dtype: object
# batter          Sunny Gupta
# batsman_runs              0
# Name: 666, dtype: object
# batter          KM Asif
# batsman_runs          0
# Name: 667, dtype: object
# batter          JL Denly
# batsman_runs           0
# Name: 668, dtype: object
# batter          ND Doshi
# batsman_runs           0
# Name: 669, dtype: object
# batter          C Nanda
# batsman_runs          0
# Name: 670, dtype: object
# batter          Yash Dayal
# batsman_runs             0
# Name: 671, dtype: object
# batter          V Pratap Singh
# batsman_runs                 0
# Name: 672, dtype: object
