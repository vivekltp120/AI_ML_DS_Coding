# %%
__author__ = "Vivek"
__author_email__ = "vivekltp120@gmail.com"

from torchtext.datasets import AG_NEWS
from transformers import AutoModelWithLMHead, AdamW
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("gpt2")

EPOCHS = 50


def preprocess_data(data_iter):
    data = [tokenizer.encode(text) for _, text in data_iter]
    return data


train_iter = AG_NEWS(split='train')
train_data = preprocess_data(train_iter)


model = AutoModelWithLMHead.from_pretrained("gpt2")
optimizer = AdamW(model.parameters())

model.train()
for epoch in range(EPOCHS):
    for batch in train_data:
        outputs = model(batch)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()


prompt = tokenizer.encode("Write a summary of the new features in the latest release of the Julia Programming Language", return_tensors="pt")
generated = model.generate(prompt)

generated_text = tokenizer.decode(generated[0])
with open("generated.txt", "w") as f:
    f.write(generated_text)
# Out:
# /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages/torchtext/__init__.py:7: SyntaxWarning: invalid escape sequence '\ '
#   "\n/!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\ \n"
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 4
#       1 __author__ = "Vivek"
#       2 __author_email__ = "vivekltp120@gmail.com"
# ----> 4 from torchtext.datasets import AG_NEWS
#       5 from transformers import AutoModelWithLMHead, AdamW
#       6 from transformers import AutoTokenizer
#
# File ~/virtual_envs/aiml_venv/lib/python3.12/site-packages/torchtext/__init__.py:18
#      15     _WARN = False
#      17 # the following import has to happen first in order to load the torchtext C++ library
# ---> 18 from torchtext import _extension  # noqa: F401
#      20 _TEXT_BUCKET = "https://download.pytorch.org/models/text/"
#      22 _CACHE_DIR = os.path.expanduser(os.path.join(_get_torch_home(), "text"))
#
# File ~/virtual_envs/aiml_venv/lib/python3.12/site-packages/torchtext/_extension.py:64
#      59     # This import is for initializing the methods registered via PyBind11
#      60     # This has to happen after the base library is loaded
#      61     from torchtext import _torchtext  # noqa
# ---> 64 _init_extension()
#
# File ~/virtual_envs/aiml_venv/lib/python3.12/site-packages/torchtext/_extension.py:58, in _init_extension()
#      55 if not _mod_utils.is_module_available("torchtext._torchtext"):
#      56     raise ImportError("torchtext C++ Extension is not found.")
# ---> 58 _load_lib("libtorchtext")
#      59 # This import is for initializing the methods registered via PyBind11
#      60 # This has to happen after the base library is loaded
#      61 from torchtext import _torchtext
#
# File ~/virtual_envs/aiml_venv/lib/python3.12/site-packages/torchtext/_extension.py:50, in _load_lib(lib)
#      48 if not path.exists():
#      49     return False
# ---> 50 torch.ops.load_library(path)
#      51 return True
#
# File ~/virtual_envs/aiml_venv/lib/python3.12/site-packages/torch/_ops.py:1392, in _Ops.load_library(self, path)
#    1387 path = _utils_internal.resolve_library_path(path)
#    1388 with dl_open_guard():
#    1389     # Import the shared library into the process, thus running its
#    1390     # static (global) initialization code in order to register custom
#    1391     # operators with the JIT.
# -> 1392     ctypes.CDLL(path)
#    1393 self.loaded_libraries.add(path)
#
# File /usr/lib/python3.12/ctypes/__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     376 self._FuncPtr = _FuncPtr
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#     381     self._handle = handle
#
# OSError: /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages/torchtext/lib/libtorchtext.so: undefined symbol: _ZN5torch6detail10class_baseC2ERKSsS3_SsRKSt9type_infoS6_

# %%
# !pip install torchtext
# Out:
# Requirement already satisfied: torchtext in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (0.18.0)
# Requirement already satisfied: tqdm in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torchtext) (4.67.1)
# Requirement already satisfied: requests in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torchtext) (2.32.3)
# Requirement already satisfied: torch>=2.3.0 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torchtext) (2.7.0)
# Requirement already satisfied: numpy in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torchtext) (1.26.4)
# Requirement already satisfied: filelock in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (4.13.2)
# Requirement already satisfied: setuptools in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (80.3.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (1.14.0)
# Requirement already satisfied: networkx in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (3.4.2)
# Requirement already satisfied: jinja2 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (3.1.6)
# Requirement already satisfied: fsspec in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from torch>=2.3.0->torchtext) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.3.0->torchtext) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from jinja2->torch>=2.3.0->torchtext) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from requests->torchtext) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from requests->torchtext) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from requests->torchtext) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vivek/virtual_envs/aiml_venv/lib/python3.12/site-packages (from requests->torchtext) (2025.4.26)
