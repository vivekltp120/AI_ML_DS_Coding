# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression

# %%
credit=pd.read_csv("creditcard.csv")
credit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#analysis of the data
# Null value or NaN check credit.isna().sum()
credit.isnull().sum()
#duplicated 
credit.duplicated().value_counts()
# Out:
# False    283726
# True       1081
# Name: count, dtype: int64

# %%
#chek for imbalance data
legit=credit[credit.Class==0]
fraud=credit[credit.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
legit=legit.sample(n=492)
print(legit.shape)
print(fraud.shape)
# Out:
# (492, 31)
# (492, 31)

# %%
# axis=0 or 'index'
# axis=1 or 'columns'
new_credit=pd.concat([legit,fraud],axis=0)

# %%
new_credit.shape
# Out:
# (984, 31)

# %%
X_credit=new_credit.drop('Class',axis=1)
Y_credit=new_credit['Class']

# %%
print(X_credit.shape)
print(Y_credit.shape)
# Out:
# (984, 30)
# (984,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X_credit,Y_credit,test_size=0.25,random_state=2)

# %%
#Model building 
from sklearn.metrics import classification_report,accuracy_score
model=LogisticRegression()
model.fit(x_train,y_train)
y_test_predict=model.predict(x_test)
y_train_predict=model.predict(x_train)

test_accuracy=accuracy_score(y_test_predict,y_test)
train_accuracy=accuracy_score(y_train_predict,y_train)

print(test_accuracy)
print(train_accuracy)

report=classification_report(y_test_predict,y_test)
print(report)
# Out:
# 0.943089430894309
# 0.9444444444444444
#               precision    recall  f1-score   support
#
#            0       0.98      0.90      0.94       123
#            1       0.91      0.98      0.95       123
#
#     accuracy                           0.94       246
#    macro avg       0.95      0.94      0.94       246
# weighted avg       0.95      0.94      0.94       246
# /home/vivek/virtual_envs/aiml_venv/lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
