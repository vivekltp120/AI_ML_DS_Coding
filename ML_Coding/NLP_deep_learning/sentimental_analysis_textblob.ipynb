# %%
from textblob import TextBlob
import textblob
sent='food is worst in the barbeque. Other resturent in this area have better food. Movie is not great but one time wacth'
for feed in sent.split('.'): 
  tbresult=TextBlob(feed)
  print('Feed - '+ feed)
  print('Sentiment -'+str(tbresult.sentiment))
  
  try:
      print('Translate into hindi --  %s' % (tbresult.translate(to='hi')))
  except Exception as e:
      print('Translation failed:', e)
  print('Tagging -- %s' % (tbresult.tags))
  print('\n\n')

#collectively  
tb=TextBlob(sent)
print('Words-'+str(tb.words))
print('Sentences-'+str(tb.sentences))
print('plural to singular-'+str(tb.words.singularize()))
print('lemmetizer-'+str(tb.words.lemmatize()))
print('stemmizer-'+str(tb.words.stem()))
print('spell correcter-'+str(tb.correct()))
print('\n\n')

#tokenizer object

tokenizer=tb.correct().tokenize()
print('tokenizer-'+str(tokenizer))
# Out:
# Feed - food is worst in the barbeque
# Sentiment -Sentiment(polarity=-1.0, subjectivity=1.0)
# Translation failed: 'TextBlob' object has no attribute 'translate'
# Tagging -- [('food', 'NN'), ('is', 'VBZ'), ('worst', 'RB'), ('in', 'IN'), ('the', 'DT'), ('barbeque', 'NN')]
#
#
#
# Feed -  Other resturent in this area have better food
# Sentiment -Sentiment(polarity=0.1875, subjectivity=0.4375)
# Translation failed: 'TextBlob' object has no attribute 'translate'
# Tagging -- [('Other', 'JJ'), ('resturent', 'NN'), ('in', 'IN'), ('this', 'DT'), ('area', 'NN'), ('have', 'VBP'), ('better', 'VBN'), ('food', 'NN')]
#
#
#
# Feed -  Movie is not great but one time wacth
# Sentiment -Sentiment(polarity=-0.4, subjectivity=0.75)
# Translation failed: 'TextBlob' object has no attribute 'translate'
# Tagging -- [('Movie', 'NNP'), ('is', 'VBZ'), ('not', 'RB'), ('great', 'JJ'), ('but', 'CC'), ('one', 'CD'), ('time', 'NN'), ('wacth', 'NN')]
#
#
#
# Words-['food', 'is', 'worst', 'in', 'the', 'barbeque', 'Other', 'resturent', 'in', 'this', 'area', 'have', 'better', 'food', 'Movie', 'is', 'not', 'great', 'but', 'one', 'time', 'wacth']
# Sentences-[Sentence("food is worst in the barbeque."), Sentence("Other resturent in this area have better food."), Sentence("Movie is not great but one time wacth")]
# plural to singular-['food', 'is', 'worst', 'in', 'the', 'barbeque', 'Other', 'resturent', 'in', 'thi', 'area', 'have', 'better', 'food', 'Movie', 'is', 'not', 'great', 'but', 'one', 'time', 'wacth']
# lemmetizer-['food', 'is', 'worst', 'in', 'the', 'barbeque', 'Other', 'resturent', 'in', 'this', 'area', 'have', 'better', 'food', 'Movie', 'is', 'not', 'great', 'but', 'one', 'time', 'wacth']
# stemmizer-['food', 'is', 'worst', 'in', 'the', 'barbequ', 'other', 'restur', 'in', 'thi', 'area', 'have', 'better', 'food', 'movi', 'is', 'not', 'great', 'but', 'one', 'time', 'wacth']
# spell correcter-food is worst in the barque. Other restaurant in this area have better food. Movie is not great but one time watch
#
#
#
# tokenizer-['food', 'is', 'worst', 'in', 'the', 'barque', '.', 'Other', 'restaurant', 'in', 'this', 'area', 'have', 'better', 'food', '.', 'Movie', 'is', 'not', 'great', 'but', 'one', 'time', 'watch']

# %%
# Out:
# Collecting textblob
#   Downloading textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: nltk>=3.9 in /home/vivek/virtual_envs/aiml_venv/lib/python3.13/site-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /home/vivek/virtual_envs/aiml_venv/lib/python3.13/site-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in /home/vivek/virtual_envs/aiml_venv/lib/python3.13/site-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /home/vivek/virtual_envs/aiml_venv/lib/python3.13/site-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /home/vivek/virtual_envs/aiml_venv/lib/python3.13/site-packages (from nltk>=3.9->textblob) (4.67.1)
# Downloading textblob-0.19.0-py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.3/624.3 kB 373.3 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: textblob
# Successfully installed textblob-0.19.0
